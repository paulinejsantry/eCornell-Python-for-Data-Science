# %% [markdown]
# ## Exploring your own dataset
#
# I will be exploring the 2023 NFL play by play data to predict if an offensive play will be a pass or rush.
#
# Data source: https://nflsavant.com/about.php
# Click "Download the 2023 play by play data"

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('pbp-2023.csv', header=0)

# %%
#remove columns which are ALL NA values
df2 = df.dropna(how = 'all')
df2.head()
# Out:
#        GameId    GameDate  Quarter  Minute  Second OffenseTeam DefenseTeam  \
# 0  2023110504  2023-11-05        2       3      15          LA          GB
# 1  2023110504  2023-11-05        2       0       5          GB          LA
# 2  2023110504  2023-11-05        2       0       4          GB          LA
# 3  2023110504  2023-11-05        2       0       0          GB          LA
# 4  2023110504  2023-11-05        3       2      13          GB          LA
#
#    Down  ToGo  YardLine  ...  IsTwoPointConversion  \
# 0     2     2        63  ...                     0
# 1     2     4        70  ...                     0
# 2     3     4        70  ...                     0
# 3     0     0       100  ...                     0
# 4     4     6        92  ...                     0
#
#    IsTwoPointConversionSuccessful  RushDirection  YardLineFixed  \
# 0                               0         CENTER             37
# 1                               0            NaN             30
# ...

# %%
#define the x and y variables
# had to remove Offensive & Defensive team since they are categorical variables

x_vars = [
    #""'OffenseTeam',
    # 'DefenseTeam',
    'Quarter',
    'Minute',
    
    'Down',
    'ToGo',
    'YardLine',
    'SeriesFirstDown',
]
y_vars = [
    'IsRush',
    'IsPass',
]
x = df2[x_vars]
y = df2[y_vars]
print(x.shape)
print(y.shape)
# Out:
# (51287, 6)
# (51287, 2)

# %%
# import 
from sklearn import svm, tree
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
# split dataset in to training & testing
datasubsets = train_test_split(x, y, random_state = 0)

(x_train, x_test, y_train, y_test) = datasubsets

print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (38465, 6)
# (12822, 6)
# (38465, 2)
# (12822, 2)

# %%
#build decision tree
clf1 = tree.DecisionTreeClassifier()
clf1.fit(x_train, y_train)
predictions1 = clf1.predict(x_test)
score1 = accuracy_score(y_test,predictions1)
print(score1)
# Out:
# 0.6360942130712838

# %%
# Accuracy is around 60% for this model
# Which makes sense since teams like to be unpredictable with their play calls
# TO DO: figure out how to incorporate which team is on Offense & Defense as variables
